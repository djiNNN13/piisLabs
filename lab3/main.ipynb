# %%
import chess
import chess.engine
import time
import chess.svg
from IPython.display import SVG, display



engine = chess.engine.SimpleEngine.popen_uci(
    "C:\Users\Yevhenii\KPIDOCS\piisLabs\lab3\stockfish_15_win_x64_avx2\stockfish_15_x64_avx2.exe")


def stockfish_eval(board_instance, isMax):
    info = engine.analyse(board_instance, chess.engine.Limit(depth=1))


    if not isMax:
        result = chess.engine.PovScore(info['score'], chess.BLACK).pov(chess.BLACK).relative.score()
    else:
        result = chess.engine.PovScore(info['score'], chess.WHITE).pov(chess.WHITE).relative.score()
    # print(result)
    if result is None:
        result = 0
    return result



def best_move_using_negaMax(board_instance, depth):
    def negaMax(board, depth, is_max):
        if depth == 0:
            return stockfish_eval(board, is_max)

        maxValueIn = -1_000_000
        for legal_move in board.legal_moves:
            move = chess.Move.from_uci(str(legal_move))
            boardCopy = board.copy()
            boardCopy.push(move)
            value = -negaMax(boardCopy, depth - 1, 1 - is_max)
            if value > maxValueIn:
                maxValueIn = value
        return maxValueIn

    maxValue = -1_000_000
    bestMove = None
    for legal_move in board_instance.legal_moves:
        move = chess.Move.from_uci(str(legal_move))
        boardCopy = board_instance.copy()
        boardCopy.push(move)
        value = -negaMax(boardCopy, depth, 1 - boardCopy.turn)
        if value > maxValue:
            maxValue = value
            bestMove = move
    return bestMove


def best_move_using_negaScout(board_instance, depth, alpha=-999999, beta=999999):
    def negaScout(board, depthIn, alphaIn, betaIn):
        if depthIn == 0:
            return stockfish_eval(board, board.turn)
        scoreIn = -1_000_000
        n = betaIn
        for legal_move in board.legal_moves:
            move = chess.Move.from_uci(str(legal_move))
            boardCopy = board.copy()
            boardCopy.push(move)
            cur = -negaScout(boardCopy, depthIn - 1, -n, -alphaIn)
            if cur > scoreIn:
                if n == beta or depthIn <= 2:
                    scoreIn = cur
                else:
                    scoreIn = -negaScout(boardCopy, depthIn - 1, -betaIn, -cur)
            if scoreIn > alphaIn:
                alphaIn = scoreIn
            if alphaIn >= betaIn:
                return alphaIn
            n = alphaIn + 1
        return scoreIn

    score = -1_000_000
    bestMove = None
    for legal_move in board_instance.legal_moves:
        move = chess.Move.from_uci(str(legal_move))
        boardCopy = board_instance.copy()
        boardCopy.push(move)
        value = -negaScout(boardCopy, depth, alpha, beta)
        if value > score:
            score = value
            bestMove = move

    return bestMove


def best_move_using_pvs(board_instance, depth, alpha=-999999, beta=999999):
    def pvs(board, depthIn, alphaIn, betaIn):
        if depthIn == 0:
            return stockfish_eval(board, board.turn)
        bSearchPvIn = True
        for legal_move in board.legal_moves:
            move = chess.Move.from_uci(str(legal_move))
            boardCopy = board.copy()
            boardCopy.push(move)
            if bSearchPvIn:
                cur = -pvs(boardCopy, depthIn - 1, -betaIn, -alphaIn)
            else:
                cur = -pvs(boardCopy, depthIn - 1, -alphaIn - 1, -alphaIn)
                if alphaIn < cur < betaIn:
                    cur = -pvs(boardCopy, depthIn - 1, -betaIn, -alphaIn)
            if cur >= betaIn:
                return betaIn
            if cur > alphaIn:
                alphaIn = cur
                bSearchPvIn = False

        return alphaIn

    score = -1_000_000
    bestMove = None
    for legal_move in board_instance.legal_moves:
        move = chess.Move.from_uci(str(legal_move))
        boardCopy = board_instance.copy()
        boardCopy.push(move)
        value = -pvs(boardCopy, depth, alpha, beta)
        if value > score:
            score = value
            bestMove = move

    return bestMove


def game_between_two_computers_pvs(depth=1):
    board = chess.Board()
    n = 0

    while board.is_checkmate() != True and board.is_fivefold_repetition() != True and board.is_seventyfive_moves() != True:
        start = time.time()
        if n % 2 == 0:
            print("WHITE Turn")
            move = best_move_using_pvs(board, depth)
        else:

            print("BLACK Turn")
            move = best_move_using_pvs(board, depth)
        end = time.time()

        if move == None:
            print("GG, checkmate")
            break

        print("Move in UCI format:", move)
        print("Time taken by Move:", end - start)
        print("Moves taken:", n)
        print("FiveFold", board.is_fivefold_repetition())
        board.push(move)
        # display(SVG(chess.svg.board(board, size=400)))
        print(board)
        print("\n")
        n = n + 1
    if board.is_fivefold_repetition():
        print("GG, fivefold")


def game_between_two_computers_negaScout(depth=1):
    board = chess.Board()
    n = 0

    while board.is_checkmate() != True and board.is_fivefold_repetition() != True and board.is_seventyfive_moves() != True:
        start = time.time()
        if n % 2 == 0:
            print("WHITE Turn")
            move = best_move_using_negaScout(board, depth)
        else:

            print("BLACK Turn")
            move = best_move_using_negaScout(board, depth)
        end = time.time()

        if move == None:
            print("GG, checkmate")
            break

        print("Move in UCI format:", move)
        print("Time taken by Move:", end - start)
        print("Moves taken:", n)
        print("FiveFold", board.is_fivefold_repetition())
        board.push(move)
        # display(SVG(chess.svg.board(board, size=400)))
        print(board)
        print("\n")
        n = n + 1
    if board.is_fivefold_repetition():
        print("GG, fivefold")


def game_between_two_computers_negaMax(depth=1):
    board = chess.Board()
    n = 0

    while board.is_checkmate() != True and board.is_fivefold_repetition() != True and board.is_seventyfive_moves() != True:
        start = time.time()
        if n % 2 == 0:
            print("WHITE Turn")
            move = best_move_using_negaMax(board, depth)
        else:

            print("BLACK Turn")
            move = best_move_using_negaMax(board, depth)
        end = time.time()

        if move == None:
            print("GG, checkmate")
            break

        print("Move in UCI format:", move)
        print("Time taken by Move:", end - start)
        print("Moves taken:", n)
        print("FiveFold", board.is_fivefold_repetition())

        board.push(move)
        # display(SVG(chess.svg.board(board, size=400)))
        print(board)
        print("\n")
        n = n + 1
    if board.is_fivefold_repetition():
        print("GG, fivefold")


if __name__ == '__main__':
    game_between_two_computers_negaMax()
    # game_between_two_computers_negaScout()
    # game_between_two_computers_pvs()
    engine.quit()
# Out:
# WHITE Turn
# Move in UCI format: e2e4
# Time taken by Move: 0.4960005283355713
# Moves taken: 0
# FiveFold False
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: c7c6
# Time taken by Move: 0.7965857982635498
# Moves taken: 1
# FiveFold False
# r n b q k b n r
# p p . p p p p p
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: d2d4
# Time taken by Move: 0.7460005283355713
# Moves taken: 2
# FiveFold False
# r n b q k b n r
# p p . p p p p p
# . . p . . . . .
# . . . . . . . .
# . . . P P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: d7d5
# Time taken by Move: 0.985668420791626
# Moves taken: 3
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . p . . . . .
# . . . p . . . .
# . . . P P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: e4e5
# Time taken by Move: 1.3520781993865967
# Moves taken: 4
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . p . . . . .
# . . . p P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: c6c5
# Time taken by Move: 1.203996181488037
# Moves taken: 5
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . . . . . . .
# . . p p P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: d4c5
# Time taken by Move: 1.4027180671691895
# Moves taken: 6
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . . . . . . .
# . . P p P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: e7e6
# Time taken by Move: 1.9400968551635742
# Moves taken: 7
# FiveFold False
# r n b q k b n r
# p p . . . p p p
# . . . . p . . .
# . . P p P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: g1f3
# Time taken by Move: 1.800138235092163
# Moves taken: 8
# FiveFold False
# r n b q k b n r
# p p . . . p p p
# . . . . p . . .
# . . P p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P . . P P P
# R N B Q K B . R
#
#
# BLACK Turn
# Move in UCI format: f8c5
# Time taken by Move: 1.7409183979034424
# Moves taken: 9
# FiveFold False
# r n b q k . n r
# p p . . . p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P . . P P P
# R N B Q K B . R
#
#
# WHITE Turn
# Move in UCI format: f1d3
# Time taken by Move: 2.06390118598938
# Moves taken: 10
# FiveFold False
# r n b q k . n r
# p p . . . p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q K . . R
#
#
# BLACK Turn
# Move in UCI format: g8e7
# Time taken by Move: 2.2355339527130127
# Moves taken: 11
# FiveFold False
# r n b q k . . r
# p p . . n p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q K . . R
#
#
# WHITE Turn
# Move in UCI format: e1g1
# Time taken by Move: 2.2561473846435547
# Moves taken: 12
# FiveFold False
# r n b q k . . r
# p p . . n p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: b8c6
# Time taken by Move: 1.6122126579284668
# Moves taken: 13
# FiveFold False
# r . b q k . . r
# p p . . n p p p
# . . n . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: b1d2
# Time taken by Move: 1.6271331310272217
# Moves taken: 14
# FiveFold False
# r . b q k . . r
# p p . . n p p p
# . . n . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: e7g6
# Time taken by Move: 1.6173949241638184
# Moves taken: 15
# FiveFold False
# r . b q k . . r
# p p . . . p p p
# . . n . p . n .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: d3g6
# Time taken by Move: 2.183544635772705
# Moves taken: 16
# FiveFold False
# r . b q k . . r
# p p . . . p p p
# . . n . p . B .
# . . b p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: h7g6
# Time taken by Move: 1.6109178066253662
# Moves taken: 17
# FiveFold False
# r . b q k . . r
# p p . . . p p .
# . . n . p . p .
# . . b p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: c2c3
# Time taken by Move: 1.5840649604797363
# Moves taken: 18
# FiveFold False
# r . b q k . . r
# p p . . . p p .
# . . n . p . p .
# . . b p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: c5e7
# Time taken by Move: 1.7402570247650146
# Moves taken: 19
# FiveFold False
# r . b q k . . r
# p p . . b p p .
# . . n . p . p .
# . . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: f1e1
# Time taken by Move: 1.3276820182800293
# Moves taken: 20
# FiveFold False
# r . b q k . . r
# p p . . b p p .
# . . n . p . p .
# . . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q R . K .
#
#
# BLACK Turn
# Move in UCI format: a7a5
# Time taken by Move: 1.801004409790039
# Moves taken: 21
# FiveFold False
# r . b q k . . r
# . p . . b p p .
# . . n . p . p .
# p . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q R . K .
#
#
# WHITE Turn
# Move in UCI format: d2f1
# Time taken by Move: 1.7785615921020508
# Moves taken: 22
# FiveFold False
# r . b q k . . r
# . p . . b p p .
# . . n . p . p .
# p . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B Q R N K .
#
#
# BLACK Turn
# Move in UCI format: b7b6
# Time taken by Move: 1.9316983222961426
# Moves taken: 23
# FiveFold False
# r . b q k . . r
# . . . . b p p .
# . p n . p . p .
# p . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B Q R N K .
#
#
# WHITE Turn
# Move in UCI format: d1a4
# Time taken by Move: 1.8092005252838135
# Moves taken: 24
# FiveFold False
# r . b q k . . r
# . . . . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B . R N K .
#
#
# BLACK Turn
# Move in UCI format: c8b7
# Time taken by Move: 1.7526085376739502
# Moves taken: 25
# FiveFold False
# r . . q k . . r
# . b . . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B . R N K .
#
#
# WHITE Turn
# Move in UCI format: c1e3
# Time taken by Move: 1.857875108718872
# Moves taken: 26
# FiveFold False
# r . . q k . . r
# . b . . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . B N . .
# P P . . . P P P
# R . . . R N K .
#
#
# BLACK Turn
# Move in UCI format: d8c7
# Time taken by Move: 1.986583948135376
# Moves taken: 27
# FiveFold False
# r . . . k . . r
# . b q . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . B N . .
# P P . . . P P P
# R . . . R N K .
#
#
# WHITE Turn
# Move in UCI format: e3g5
# Time taken by Move: 2.3362927436828613
# Moves taken: 28
# FiveFold False
# r . . . k . . r
# . b q . b p p .
# . p n . p . p .
# p . . p P . B .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . . . R N K .
#
#
# BLACK Turn
# Move in UCI format: e7g5
# Time taken by Move: 2.365295886993408
# Moves taken: 29
# FiveFold False
# r . . . k . . r
# . b q . . p p .
# . p n . p . p .
# p . . p P . b .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . . . R N K .
#
#
# WHITE Turn
# Move in UCI format: f3g5
# Time taken by Move: 2.1030406951904297
# Moves taken: 30
# FiveFold False
# r . . . k . . r
# . b q . . p p .
# . p n . p . p .
# p . . p P . N .
# Q . . . . . . .
# . . P . . . . .
# P P . . . P P P
# R . . . R N K .
#
#
# BLACK Turn
# Move in UCI format: b7a6
# Time taken by Move: 1.7615125179290771
# Moves taken: 31
# FiveFold False
# r . . . k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . . .
# . . P . . . . .
# P P . . . P P P
# R . . . R N K .
#
#
# WHITE Turn
# Move in UCI format: f1e3
# Time taken by Move: 2.2267675399780273
# Moves taken: 32
# FiveFold False
# r . . . k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . . .
# . . P . N . . .
# P P . . . P P P
# R . . . R . K .
#
#
# BLACK Turn
# Move in UCI format: h8h5
# Time taken by Move: 2.4473085403442383
# Moves taken: 33
# FiveFold False
# r . . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . .
# . . P . N . . .
# P P . . . P P P
# R . . . R . K .
#
#
# WHITE Turn
# Move in UCI format: h2h4
# Time taken by Move: 2.544283390045166
# Moves taken: 34
# FiveFold False
# r . . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# R . . . R . K .
#
#
# BLACK Turn
# Move in UCI format: a8b8
# Time taken by Move: 1.9904673099517822
# Moves taken: 35
# FiveFold False
# . r . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# R . . . R . K .
#
#
# WHITE Turn
# Move in UCI format: a1d1
# Time taken by Move: 1.9834282398223877
# Moves taken: 36
# FiveFold False
# . r . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: b8d8
# Time taken by Move: 1.8281300067901611
# Moves taken: 37
# FiveFold False
# . . . r k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: g2g3
# Time taken by Move: 2.4267988204956055
# Moves taken: 38
# FiveFold False
# . . . r k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . P .
# P P . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: h5h8
# Time taken by Move: 2.3605525493621826
# Moves taken: 39
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . . P
# . . P . N . P .
# P P . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: e3g4
# Time taken by Move: 2.4092466831207275
# Moves taken: 40
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . N P
# . . P . . . P .
# P P . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: a6c4
# Time taken by Move: 1.9806945323944092
# Moves taken: 41
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . p n . p . p .
# p . . p P . N .
# Q . b . . . N P
# . . P . . . P .
# P P . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: b2b3
# Time taken by Move: 1.73469877243042
# Moves taken: 42
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . p n . p . p .
# p . . p P . N .
# Q . b . . . N P
# . P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: b6b5
# Time taken by Move: 1.7699763774871826
# Moves taken: 43
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p p . p P . N .
# Q . b . . . N P
# . P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: a4a3
# Time taken by Move: 2.2338595390319824
# Moves taken: 44
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p p . p P . N .
# . . b . . . N P
# Q P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: b5b4
# Time taken by Move: 2.106527328491211
# Moves taken: 45
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p . . p P . N .
# . p b . . . N P
# Q P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: c3b4
# Time taken by Move: 2.15140700340271
# Moves taken: 46
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p . . p P . N .
# . P b . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: c4b5
# Time taken by Move: 2.0723395347595215
# Moves taken: 47
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p b . p P . N .
# . P . . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: b4a5
# Time taken by Move: 1.9063098430633545
# Moves taken: 48
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# P b . p P . N .
# . . . . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: c7a5
# Time taken by Move: 2.0691957473754883
# Moves taken: 49
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# q b . p P . N .
# . . . . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: a3a5
# Time taken by Move: 2.0623722076416016
# Moves taken: 50
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# Q b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: c6a5
# Time taken by Move: 1.7362079620361328
# Moves taken: 51
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# n b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: d1c1
# Time taken by Move: 1.9856288433074951
# Moves taken: 52
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# n b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: a5c6
# Time taken by Move: 1.836714506149292
# Moves taken: 53
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# . b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: a2a4
# Time taken by Move: 1.631155252456665
# Moves taken: 54
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# . b . p P . N .
# P . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: c6b4
# Time taken by Move: 1.7792444229125977
# Moves taken: 55
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# . b . p P . N .
# P n . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: a4b5
# Time taken by Move: 1.598341703414917
# Moves taken: 56
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# . P . p P . N .
# . n . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: b4d3
# Time taken by Move: 1.324730634689331
# Moves taken: 57
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# . P . p P . N .
# . . . . . . N P
# . P . n . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: g5f7
# Time taken by Move: 1.553046703338623
# Moves taken: 58
# FiveFold False
# . . . r k . . r
# . . . . . N p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . n . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: e8f7
# Time taken by Move: 1.4966235160827637
# Moves taken: 59
# FiveFold False
# . . . r . . . r
# . . . . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . n . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: c1c3
# Time taken by Move: 1.4995253086090088
# Moves taken: 60
# FiveFold False
# . . . r . . . r
# . . . . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P R n . . P .
# . . . . . P . .
# . . . . R . K .
#
#
# BLACK Turn
# Move in UCI format: d3e1
# Time taken by Move: 1.4940624237060547
# Moves taken: 61
# FiveFold False
# . . . r . . . r
# . . . . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P R . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# WHITE Turn
# Move in UCI format: c3c7
# Time taken by Move: 1.0040647983551025
# Moves taken: 62
# FiveFold False
# . . . r . . . r
# . . R . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# BLACK Turn
# Move in UCI format: f7g8
# Time taken by Move: 0.17501163482666016
# Moves taken: 63
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# WHITE Turn
# Move in UCI format: b5b6
# Time taken by Move: 0.7030215263366699
# Moves taken: 64
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# BLACK Turn
# Move in UCI format: e1f3
# Time taken by Move: 0.7652359008789062
# Moves taken: 65
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . . . . N P
# . P . . . n P .
# . . . . . P . .
# . . . . . . K .
#
#
# WHITE Turn
# Move in UCI format: g1g2
# Time taken by Move: 0.17017388343811035
# Moves taken: 66
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . . . . N P
# . P . . . n P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f3d4
# Time taken by Move: 1.0375006198883057
# Moves taken: 67
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . n . . N P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b6b7
# Time taken by Move: 0.8923709392547607
# Moves taken: 68
# FiveFold False
# . . . r . . k r
# . P R . . . p .
# . . . . p . p .
# . . . p P . . .
# . . . n . . N P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d8b8
# Time taken by Move: 1.1158065795898438
# Moves taken: 69
# FiveFold False
# . r . . . . k r
# . P R . . . p .
# . . . . p . p .
# . . . p P . . .
# . . . n . . N P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: g4f6
# Time taken by Move: 0.8316924571990967
# Moves taken: 70
# FiveFold False
# . r . . . . k r
# . P R . . . p .
# . . . . p N p .
# . . . p P . . .
# . . . n . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g7f6
# Time taken by Move: 0.0950019359588623
# Moves taken: 71
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p p p .
# . . . p P . . .
# . . . n . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: e5f6
# Time taken by Move: 0.9324493408203125
# Moves taken: 72
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P p .
# . . . p . . . .
# . . . n . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d4f5
# Time taken by Move: 0.9583380222320557
# Moves taken: 73
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P p .
# . . . p . n . .
# . . . . . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h4h5
# Time taken by Move: 0.9732720851898193
# Moves taken: 74
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P p .
# . . . p . n . P
# . . . . . . . .
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g6h5
# Time taken by Move: 0.9813597202301025
# Moves taken: 75
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . . . p . n . p
# . . . . . . . .
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b3b4
# Time taken by Move: 0.8733828067779541
# Moves taken: 76
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . . . p . n . p
# . P . . . . . .
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: h5h4
# Time taken by Move: 1.0730020999908447
# Moves taken: 77
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . . . p . n . .
# . P . . . . . p
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b4b5
# Time taken by Move: 0.9887583255767822
# Moves taken: 78
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . p . n . .
# . . . . . . . p
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d5d4
# Time taken by Move: 1.0207312107086182
# Moves taken: 79
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . p . . . p
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: g3h4
# Time taken by Move: 0.9801690578460693
# Moves taken: 80
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . p . . . P
# . . . . . . . .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d4d3
# Time taken by Move: 0.8756847381591797
# Moves taken: 81
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: g2f1
# Time taken by Move: 0.8664340972900391
# Moves taken: 82
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# BLACK Turn
# Move in UCI format: g8f8
# Time taken by Move: 0.7246706485748291
# Moves taken: 83
# FiveFold False
# . r . . . k . r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# WHITE Turn
# Move in UCI format: c7c8
# Time taken by Move: 0.7814111709594727
# Moves taken: 84
# FiveFold False
# . r R . . k . r
# . P . . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# BLACK Turn
# Move in UCI format: f8f7
# Time taken by Move: 0.07899975776672363
# Moves taken: 85
# FiveFold False
# . r R . . . . r
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# WHITE Turn
# Move in UCI format: c8h8
# Time taken by Move: 0.975996732711792
# Moves taken: 86
# FiveFold False
# . r . . . . . R
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# BLACK Turn
# Move in UCI format: b8h8
# Time taken by Move: 0.6476967334747314
# Moves taken: 87
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# WHITE Turn
# Move in UCI format: f1e1
# Time taken by Move: 0.5486931800842285
# Moves taken: 88
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . K . . .
#
#
# BLACK Turn
# Move in UCI format: f5d6
# Time taken by Move: 0.5243327617645264
# Moves taken: 89
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . n p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . K . . .
#
#
# WHITE Turn
# Move in UCI format: e1d2
# Time taken by Move: 0.5170049667358398
# Moves taken: 90
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . n p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . . . .
# . . . K . P . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d6b7
# Time taken by Move: 0.6356832981109619
# Moves taken: 91
# FiveFold False
# . . . . . . . r
# . n . . . k . .
# . . . . p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . . . .
# . . . K . P . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: f2f3
# Time taken by Move: 0.47099971771240234
# Moves taken: 92
# FiveFold False
# . . . . . . . r
# . n . . . k . .
# . . . . p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b7d6
# Time taken by Move: 0.34799957275390625
# Moves taken: 93
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . . . n p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b5b6
# Time taken by Move: 0.432919979095459
# Moves taken: 94
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . P . n p P . .
# . . . . . . . .
# . . . . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d6c4
# Time taken by Move: 0.39772725105285645
# Moves taken: 95
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . P . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d2d3
# Time taken by Move: 0.29622602462768555
# Moves taken: 96
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . P . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: h8c8
# Time taken by Move: 0.5559988021850586
# Moves taken: 97
# FiveFold False
# . . r . . . . .
# . . . . . k . .
# . P . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b6b7
# Time taken by Move: 0.43262481689453125
# Moves taken: 98
# FiveFold False
# . . r . . . . .
# . P . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: c8b8
# Time taken by Move: 0.7590236663818359
# Moves taken: 99
# FiveFold False
# . r . . . . . .
# . P . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3c4
# Time taken by Move: 0.3330252170562744
# Moves taken: 100
# FiveFold False
# . r . . . . . .
# . P . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . K . . . . P
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b8b7
# Time taken by Move: 0.39597439765930176
# Moves taken: 101
# FiveFold False
# . . . . . . . .
# . r . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . K . . . . P
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h4h5
# Time taken by Move: 0.22699880599975586
# Moves taken: 102
# FiveFold False
# . . . . . . . .
# . r . . . k . .
# . . . . p P . .
# . . . . . . . P
# . . K . . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f7f6
# Time taken by Move: 0.24680304527282715
# Moves taken: 103
# FiveFold False
# . . . . . . . .
# . r . . . . . .
# . . . . p k . .
# . . . . . . . P
# . . K . . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c4d4
# Time taken by Move: 0.23674726486206055
# Moves taken: 104
# FiveFold False
# . . . . . . . .
# . r . . . . . .
# . . . . p k . .
# . . . . . . . P
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b7b5
# Time taken by Move: 0.34938764572143555
# Moves taken: 105
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . r . . . . . P
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h5h6
# Time taken by Move: 0.28970766067504883
# Moves taken: 106
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p k . P
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f6g6
# Time taken by Move: 0.26500511169433594
# Moves taken: 107
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . k P
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h6h7
# Time taken by Move: 0.3432350158691406
# Moves taken: 108
# FiveFold False
# . . . . . . . .
# . . . . . . . P
# . . . . p . k .
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g6h7
# Time taken by Move: 0.49301648139953613
# Moves taken: 109
# FiveFold False
# . . . . . . . .
# . . . . . . . k
# . . . . p . . .
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d4d3
# Time taken by Move: 0.24100065231323242
# Moves taken: 110
# FiveFold False
# . . . . . . . .
# . . . . . . . k
# . . . . p . . .
# . r . . . . . .
# . . . . . . . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: h7g6
# Time taken by Move: 0.45716261863708496
# Moves taken: 111
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . k .
# . r . . . . . .
# . . . . . . . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3e3
# Time taken by Move: 0.45964574813842773
# Moves taken: 112
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . k .
# . r . . . . . .
# . . . . . . . .
# . . . . K P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g6f5
# Time taken by Move: 0.4246854782104492
# Moves taken: 113
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . k . .
# . . . . . . . .
# . . . . K P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: e3d3
# Time taken by Move: 0.19599533081054688
# Moves taken: 114
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . k . .
# . . . . . . . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f5f4
# Time taken by Move: 0.27077698707580566
# Moves taken: 115
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . . . .
# . . . . . k . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3e2
# Time taken by Move: 0.26102161407470703
# Moves taken: 116
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . . . .
# . . . . . k . .
# . . . . . P . .
# . . . . K . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b5b2
# Time taken by Move: 0.2879812717437744
# Moves taken: 117
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . P . .
# . r . . K . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: e2d1
# Time taken by Move: 0.17003226280212402
# Moves taken: 118
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . P . .
# . r . . . . . .
# . . . K . . . .
#
#
# BLACK Turn
# Move in UCI format: f4f3
# Time taken by Move: 0.16951346397399902
# Moves taken: 119
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . r . . . . . .
# . . . K . . . .
#
#
# WHITE Turn
# Move in UCI format: d1e1
# Time taken by Move: 0.11101603507995605
# Moves taken: 120
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . r . . . . . .
# . . . . K . . .
#
#
# BLACK Turn
# Move in UCI format: b2b1
# Time taken by Move: 0.12598204612731934
# Moves taken: 121
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . . . .
# . r . . K . . .
#
#
# WHITE Turn
# Move in UCI format: e1d2
# Time taken by Move: 0.05500388145446777
# Moves taken: 122
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . K . . . .
# . r . . . . . .
#
#
# BLACK Turn
# Move in UCI format: e6e5
# Time taken by Move: 0.24599504470825195
# Moves taken: 123
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . k . .
# . . . K . . . .
# . r . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d2d3
# Time taken by Move: 0.12728500366210938
# Moves taken: 124
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . K . k . .
# . . . . . . . .
# . r . . . . . .
#
#
# BLACK Turn
# Move in UCI format: e5e4
# Time taken by Move: 0.18023276329040527
# Moves taken: 125
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . K . k . .
# . . . . . . . .
# . r . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3c2
# Time taken by Move: 0.20871210098266602
# Moves taken: 126
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
# . . K . . . . .
# . r . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b1a1
# Time taken by Move: 0.16435813903808594
# Moves taken: 127
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
# . . K . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c2c3
# Time taken by Move: 0.1586747169494629
# Moves taken: 128
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . K . . k . .
# . . . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: e4e3
# Time taken by Move: 0.28844618797302246
# Moves taken: 129
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.2832767963409424
# Moves taken: 130
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a1h1
# Time taken by Move: 0.22970175743103027
# Moves taken: 131
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.25568509101867676
# Moves taken: 132
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: h1a1
# Time taken by Move: 0.27899956703186035
# Moves taken: 133
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.2839996814727783
# Moves taken: 134
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a1h1
# Time taken by Move: 0.21982192993164062
# Moves taken: 135
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.31800079345703125
# Moves taken: 136
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: h1a1
# Time taken by Move: 0.3036692142486572
# Moves taken: 137
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.35939908027648926
# Moves taken: 138
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a1h1
# Time taken by Move: 0.2740025520324707
# Moves taken: 139
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.2369987964630127
# Moves taken: 140
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: e3e2
# Time taken by Move: 0.33872270584106445
# Moves taken: 141
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: c3b3
# Time taken by Move: 0.41499876976013184
# Moves taken: 142
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: h1d1
# Time taken by Move: 0.3964858055114746
# Moves taken: 143
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . r . . . .
#
#
# WHITE Turn
# Move in UCI format: b3a2
# Time taken by Move: 0.3886983394622803
# Moves taken: 144
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# K . . . p . . .
# . . . r . . . .
#
#
# BLACK Turn
# Move in UCI format: d1g1
# Time taken by Move: 0.18900275230407715
# Moves taken: 145
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# K . . . p . . .
# . . . . . . r .
#
#
# WHITE Turn
# Move in UCI format: a2a3
# Time taken by Move: 0.1933155059814453
# Moves taken: 146
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . . k . .
# . . . . p . . .
# . . . . . . r .
#
#
# BLACK Turn
# Move in UCI format: g1g7
# Time taken by Move: 0.27365589141845703
# Moves taken: 147
# FiveFold False
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: a3b3
# Time taken by Move: 0.26587653160095215
# Moves taken: 148
# FiveFold False
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g7g5
# Time taken by Move: 0.45404696464538574
# Moves taken: 149
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b3c4
# Time taken by Move: 0.41468191146850586
# Moves taken: 150
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . K . . . . .
# . . . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g5a5
# Time taken by Move: 0.314450740814209
# Moves taken: 151
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . K . . . . .
# . . . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c4c3
# Time taken by Move: 0.266512393951416
# Moves taken: 152
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a5a8
# Time taken by Move: 0.4079868793487549
# Moves taken: 153
# FiveFold False
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3d2
# Time taken by Move: 0.43703556060791016
# Moves taken: 154
# FiveFold False
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . K p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a8a5
# Time taken by Move: 0.32596731185913086
# Moves taken: 155
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . K p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d2c3
# Time taken by Move: 0.29739880561828613
# Moves taken: 156
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a5a7
# Time taken by Move: 0.43165159225463867
# Moves taken: 157
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b3
# Time taken by Move: 0.41164302825927734
# Moves taken: 158
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f3g4
# Time taken by Move: 0.39064717292785645
# Moves taken: 159
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . K . . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b3c4
# Time taken by Move: 0.3439979553222656
# Moves taken: 160
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . k .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a7d7
# Time taken by Move: 0.5208075046539307
# Moves taken: 161
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . k .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c4c3
# Time taken by Move: 0.3390014171600342
# Moves taken: 162
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . K . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g4f3
# Time taken by Move: 0.38342976570129395
# Moves taken: 163
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.2949967384338379
# Moves taken: 164
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . K . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f3g4
# Time taken by Move: 0.4795846939086914
# Moves taken: 165
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . . . . .
# . K . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b2b1
# Time taken by Move: 0.5214447975158691
# Moves taken: 166
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . . . . .
# . . . . p . . .
# . K . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g4g3
# Time taken by Move: 0.4357872009277344
# Moves taken: 167
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . p . . .
# . K . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b1a2
# Time taken by Move: 0.30089426040649414
# Moves taken: 168
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# K . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g3g2
# Time taken by Move: 0.2924163341522217
# Moves taken: 169
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . p . k .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: a2b2
# Time taken by Move: 0.30199694633483887
# Moves taken: 170
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . p . k .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d7d6
# Time taken by Move: 0.4356417655944824
# Moves taken: 171
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . p . k .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.490018367767334
# Moves taken: 172
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . . .
# . . . . p . k .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g2f1
# Time taken by Move: 0.366652250289917
# Moves taken: 173
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: c3b4
# Time taken by Move: 0.26500940322875977
# Moves taken: 174
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . K . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: d6d5
# Time taken by Move: 0.42566537857055664
# Moves taken: 175
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . K . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: b4a4
# Time taken by Move: 0.26276636123657227
# Moves taken: 176
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# K . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: d5g5
# Time taken by Move: 0.21268534660339355
# Moves taken: 177
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# K . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: a4b3
# Time taken by Move: 0.16711759567260742
# Moves taken: 178
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . K . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: g5b5
# Time taken by Move: 0.3792436122894287
# Moves taken: 179
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . K . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: b3c2
# Time taken by Move: 0.3601949214935303
# Moves taken: 180
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: e2e1q
# Time taken by Move: 0.2567124366760254
# Moves taken: 181
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . . .
# . . . . q k . .
#
#
# WHITE Turn
# Move in UCI format: c2d3
# Time taken by Move: 0.09251618385314941
# Moves taken: 182
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . q k . .
#
#
# BLACK Turn
# Move in UCI format: b5b2
# Time taken by Move: 0.37600016593933105
# Moves taken: 183
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . K . . . .
# . r . . . . . .
# . . . . q k . .
#
#
# WHITE Turn
# Move in UCI format: d3d4
# Time taken by Move: 0.18137145042419434
# Moves taken: 184
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . q k . .
#
#
# BLACK Turn
# Move in UCI format: e1a5
# Time taken by Move: 0.4223661422729492
# Moves taken: 185
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# q . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: d4e4
# Time taken by Move: 0.3919994831085205
# Moves taken: 186
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# q . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: a5c3
# Time taken by Move: 0.5109767913818359
# Moves taken: 187
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . K . . .
# . . q . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: e4d5
# Time taken by Move: 0.2970004081726074
# Moves taken: 188
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . q . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: b2b6
# Time taken by Move: 0.430553674697876
# Moves taken: 189
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: d5e4
# Time taken by Move: 0.09499883651733398
# Moves taken: 190
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . . K . . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: b6b5
# Time taken by Move: 0.5382575988769531
# Moves taken: 191
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . K . . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: e4f4
# Time taken by Move: 0.12186527252197266
# Moves taken: 192
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . K . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: c3d3
# Time taken by Move: 0.3580024242401123
# Moves taken: 193
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . K . .
# . . . q . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: f4g4
# Time taken by Move: 0.08899259567260742
# Moves taken: 194
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . K .
# . . . q . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: d3e3
# Time taken by Move: 0.270967960357666
# Moves taken: 195
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . K .
# . . . . q . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: g4h4
# Time taken by Move: 0.12700557708740234
# Moves taken: 196
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . K
# . . . . q . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: b5g5
# Time taken by Move: 0.21999454498291016
# Moves taken: 197
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . . . . . . K
# . . . . q . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# GG, checkmate
